# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,100)
y = np.array([
    -28.935262435621514,
    63.62401061069032,
    27.068955469757185,
    25.723129715500633,
    7.968584851323173,
    61.93815699673431,
    76.12270557823867,
    8.461717788441014,
    -24.387312650650852,
    88.61324660947068,
    -24.526037540328748,
    74.85470439344044,
    0.5541109339254717,
    -8.180504556164959,
    18.99814729596467,
    11.765117948708047,
    -1.1020695531178184,
    27.903676195753114,
    55.93508143363561,
    54.93412299850868,
    56.257014777842016,
    -4.545763287425814,
    36.58885227356286,
    72.53870868187519,
    49.48829100672915,
    0.9578207861137891,
    45.93802916177013,
    21.07826915883246,
    -8.684415662019223,
    59.02472479039157,
    -10.139197911502556,
    36.57978468144679,
    15.522220547935873,
    11.920518074990888,
    32.43108701310322,
    47.49060384788047,
    -30.820375394539056,
    68.65958521196453,
    30.842508795007333,
    1.1200239664215985,
    50.07144156059111,
    74.42017148890423,
    3.753796905350228,
    34.822894184586886,
    -0.47186772917032016,
    95.42617167350305,
    37.34122766526489,
    51.59278749094101,
    54.98007591109785,
    34.8312524934304,
    -37.888178006757954,
    47.007962378780874,
    26.225791131499626,
    18.375100503587824,
    22.673406933909177,
    38.33790647328634,
    -8.68275315546696,
    -11.501917645063799,
    46.17893905646119,
    38.88788773551508,
    -16.557837604974203,
    63.14964565367582,
    0.9410642653153445,
    63.08071624254868,
    -20.291241478187878,
    30.966517483107125,
    -10.406467483015891,
    3.168772781308821,
    48.42391121624409,
    8.51162593021865,
    -16.964397474874787,
    32.68990268334194,
    -34.114755773259674,
    40.55704846527913,
    19.71288058450731,
    1.1885848095389673,
    -21.295599598154894,
    -19.207522129629663,
    40.58247134874952,
    -26.719751088626513,
    53.95110992314545,
    -10.105742880295743,
    10.697502846427124,
    0.5771878709451741,
    -9.051785860501537,
    53.01361880333095,
    -12.287058284503374,
    -15.928058871450716,
    53.57559872846083,
    24.811797104800092,
    85.97596329095563,
    33.83135480223882,
    48.45220226563209,
    38.089344635514756,
    44.95862692911261,
    20.450339206229724,
    -13.131474982872739,
    33.589079860772145,
    -22.855454129782593,
    4.617271196475077,
])

plt.figure(figsize=(35, 20))

plt.subplot(2,2,1)
plt.stem(x, y)   

plt.subplot(2,2,2)
plt.step(x, y) 

plt.subplot(2,2,3)
plt.bar(x, y)

plt.subplot(2,2,4)
y2=np.array([x*2 for x in y])
plt.annotate(
    'Макс (y1)',
    xy=(np.where(y==np.max(y))[0], np.max(y)),
    xytext=[80, 170],
    arrowprops=dict(arrowstyle="wedge")
)
plt.annotate(
    'Макс (y2)',
    xy=(np.where(y2==np.max(y2))[0], np.max(y2)),
    xytext=[70, 180],
    arrowprops=dict(arrowstyle="wedge")
)
plt.grid(True)
plt.plot(x, y, label='y1=f(x)')
plt.plot(x, y2, ':', label='y2=2*f(x)')
plt.legend()

plt.show()
